# %%
#导入cv模块
import cv2 as cv
from matplotlib import pyplot as plt

#检测函数
def face_detect():
    print("face_detect")
    # gary = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    #face_detect = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
    # 这个XML文件保存的是系统预训练的如何识别人脸特征的信息
    # 也有其他不同目的的XML文件，可以在网上下载
    face_detect = cv.CascadeClassifier('./02_data/haarcascade_frontalface_alt.xml')
    face = face_detect.detectMultiScale(img)
    for x,y,w,h in face:
        cv.rectangle(img,(x,y),(x+w,y+h),color=(255,0,0),thickness=2)
    return img

#读取图像

img = cv.imread('./02_data/1927-solvay-conference-colorful.jpg')
#img = cv.imread('./02_data/yh_color.jpg')
#检测函数
img = face_detect()

# 使用 Matplotlib 显示图像
plt.imshow(img)
plt.axis('off')  # 不显示坐标尺寸
plt.show()

print("Done!")
# Out:
# face_detect
# Done!
